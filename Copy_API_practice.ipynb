# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
import requests
requests.__version__
# Out:
# '2.27.1'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
#Add units=Imperial ???

# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=imperial&appid=

url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=imperial&appid=" + weather_api_key

# %%
# Create an endpoint URL for a city.
#url specifies weather to the time the code was ran last
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=imperial&appid=2bc1023b8dad77b8640c75b326f719de&q=Boston

# %%
# video example
city = "London"
query_url = url + "&q=" + city

weather_responses = requests.get(query_url)
weather_json = weather_responses.json()

print(query_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=imperial&appid=2bc1023b8dad77b8640c75b326f719de&q=London

# %%
#why do I not have the same array as in the video? is it because I left the
# units=Imperial within my url? 
# I was missing an '=' after the '&q' smh
weather_json.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
#printed out in Farhenheit thanks to the imperial units
weather_json.get("main")
# Out:
# {'temp': 59.72,
#  'feels_like': 58.26,
#  'temp_min': 53.35,
#  'temp_max': 65.3,
#  'pressure': 1022,
#  'humidity': 61}

# %%
# Make a 'Get' request for the city weather.

#this outputs <Response [200]>
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.

# 404 error
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":25.02,"feels_like":12.42,"temp_min":21.61,"temp_max":27.95,"pressure":1007,"humidity":59},"visibility":10000,"wind":{"speed":20.71,"deg":300,"gust":27.63},"clouds":{"all":75},"dt":1648472701,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1648463613,"sunset":1648508688},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 25.02,
#   'feels_like': 12.42,
#   'temp_min': 21.61,
#   'temp_max': 27.95,
#   'pressure': 1007,
#   'humidity': 59},
#  'visibility': 10000,
#  'wind': {'speed': 20.71, 'deg': 300, 'gust': 27.63},
#  'clouds': {'all': 75},
#  'dt': 1648472701,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1648463613,
#   'sunset': 1648508688},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Response [200] is a valid response

# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")


# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Bston" #spelled wrong, hence not found
#city_weather = requests.get(city_url)
#if city_weather.status_code == 200:
#    print(f"City Weather found.")
#else:
 #   print(f"City weather not found.")
    
city_weather.json()
# Out:
# City Weather found.
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 25.02,
#   'feels_like': 12.42,
#   'temp_min': 21.61,
#   'temp_max': 27.95,
#   'pressure': 1007,
#   'humidity': 59},
#  'visibility': 10000,
#  'wind': {'speed': 20.71, 'deg': 300, 'gust': 27.63},
#  'clouds': {'all': 75},
#  'dt': 1648472701,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1648463613,
#   'sunset': 1648508688},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# GEt JSON data
boston_data = city_weather.json()

boston_data['sys']["country"]

boston_data["dt"]
# Out:
# 1648472701

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 27.95 59 75 20.71

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-03-28 13:05:01'

# %%
#psuedo code for pulling weather data from website for multiple cities

#import dependencies / initialize empty list
import time
from datetime import datetime
import requests
from config import weather_api_key
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

city_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
#is this how you unzip?
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# albany au
# broken hill au
# udimskiy ru
# kruisfontein za
# tecoanapa mx
# rikitea pf
# bambous virieux mu
# victoria sc
# mar del plata ar
# nikolskoye ru
# butaritari ki
# mys shmidta ru
# hilo us
# rikitea pf
# cape town za
# kapaa us
# bluff nz
# carnarvon au
# cape town za
# ushuaia ar
# longyearbyen sj
# oyama jp
# svetlaya ru
# sungaipenuh id
# san cristobal ec
# vilyuysk ru
# illoqqortoormiut gl
# bengkulu id
# ushuaia ar
# zelenoborskiy ru
# tuktoyaktuk ca
# punta arenas cl
# albany au
# cherskiy ru
# kedrovyy ru
# hobart au
# izhmorskiy ru
# bluff nz
# kovur in
# kapaa us
# vaini to
# chokurdakh ru
# fort nelson ca
# rapar in
# ushuaia ar
# alofi nu
# gizo sb
# khonuu ru
# champerico gt
# kutum sd
# sao filipe cv
# sao filipe cv
# barrow us
# airai pw
# saint-philippe re
# naze jp
# los llanos de aridane es
# aras no
# qaanaaq gl
# kapaa us
# severo-kurilsk ru
# punta arenas cl
# rikitea pf
# bluff nz
# taoudenni ml
# lagoa pt
# hermanus za
# albany au
# busselton au
# portland au
# asau tv
# sorong id
# rikitea pf
# atuona pf
# bandarbeyla so
# mataura pf
# dikson ru
# norman wells ca
# oudtshoorn za
# ucluelet ca
# waipawa nz
# pak phanang th
# saint-pierre pm
# avarua ck
# kodiak us
# salekhard ru
# longyearbyen sj
# barentsburg sj
# hihifo to
# taolanaro mg
# kenora ca
# albany au
# verkhnyaya inta ru
# charters towers au
# vila franca do campo pt
# rikitea pf
# vaini to
# faanui pf
# qaanaaq gl
# westport nz
# bredasdorp za
# lethem gy
# dikson ru
# egvekinot ru
# pisco pe
# linxia cn
# punta arenas cl
# puerto ayora ec
# amderma ru
# bolungarvik is
# ribeira grande pt
# cape town za
# parelhas br
# ancud cl
# bellefontaine us
# ambulu id
# vaini to
# ust-kuyga ru
# taltal cl
# jamestown sh
# samsun tr
# cayenne gf
# punta arenas cl
# vaini to
# muriti tz
# hermanus za
# saskylakh ru
# rikitea pf
# port alfred za
# yushan cn
# mataura pf
# pangkalanbuun id
# georgetown sh
# rikitea pf
# albany au
# grand river south east mu
# port alfred za
# souillac mu
# yongchang cn
# hastings ca
# talaya ru
# busselton au
# hobart au
# busselton au
# waipawa nz
# yellowknife ca
# arraial do cabo br
# rocha uy
# seddon nz
# amahai id
# jamestown sh
# cherskiy ru
# jamestown sh
# amderma ru
# upernavik gl
# canitas mx
# jamestown sh
# leningradskiy ru
# jiayuguan cn
# montepuez mz
# kavaratti in
# avarua ck
# saint anthony ca
# belmonte br
# bluff nz
# harrisburg us
# carnarvon au
# ketchikan us
# rikitea pf
# punta arenas cl
# iztapa gt
# tasiilaq gl
# arraial do cabo br
# agustin codazzi co
# arman ru
# provideniya ru
# bluff nz
# vaini to
# sibolga id
# busselton au
# barentsburg sj
# port elizabeth za
# albany au
# segezha ru
# hermanus za
# jamestown sh
# torbay ca
# jamestown sh
# yellowknife ca
# dikson ru
# illoqqortoormiut gl
# libertador general san martin ar
# mahebourg mu
# raudeberg no
# fort-shevchenko kz
# cape town za
# sentyabrskiy ru
# bethel us
# grand gaube mu
# tuktoyaktuk ca
# victoria point au
# kushima jp
# marang my
# gaogou cn
# zaykovo ru
# srednekolymsk ru
# katsuura jp
# rikitea pf
# nizhneyansk ru
# codrington ag
# la ligua cl
# rio casca br
# mataura pf
# kruisfontein za
# tiksi ru
# galiwinku au
# kapaa us
# busselton au
# carnarvon au
# abu dhabi ae
# east london za
# avarua ck
# atuona pf
# mormugao in
# seoul kr
# sakakah sa
# taolanaro mg
# bluff nz
# yumen cn
# ceres za
# shiraz ir
# ushuaia ar
# taoudenni ml
# cape town za
# pisco pe
# chalette-sur-loing fr
# puerto escondido mx
# busselton au
# hasaki jp
# sao filipe cv
# victoria sc
# ostrovnoy ru
# ushuaia ar
# northam au
# butaritari ki
# saint-philippe re
# iracoubo gf
# harlow gb
# cape town za
# bengkulu id
# abu dhabi ae
# saint-francois gp
# mandalgovi mn
# albany au
# shakawe bw
# bengkulu id
# east london za
# mogadishu so
# nueva loja ec
# talnakh ru
# bengkulu id
# airai pw
# pestravka ru
# east london za
# qaanaaq gl
# svirstroy ru
# okhotsk ru
# zlatoustovsk ru
# puerto ayora ec
# jiazi cn
# puerto ayora ec
# chimoio mz
# hithadhoo mv
# hilo us
# cidreira br
# ushuaia ar
# saint george bm
# lebork pl
# tsihombe mg
# perth au
# hilo us
# belmonte br
# saint-georges gf
# siocon ph
# mataura pf
# avera pf
# ushuaia ar
# mount gambier au
# yaan cn
# mataura pf
# narsaq gl
# yellowknife ca
# severo-kurilsk ru
# shelburne ca
# anadyr ru
# atuona pf
# albany au
# rikitea pf
# padang id
# dzhusaly kz
# churapcha ru
# romanovo ru
# gat ly
# albany au
# praya id
# ahipara nz
# port elizabeth za
# saint george bm
# hithadhoo mv
# tiksi ru
# panchgani in
# narsaq gl
# port augusta au
# yellowknife ca
# lorengau pg
# san quintin mx
# kahului us
# mataura pf
# vaini to
# rocha uy
# tabiauea ki
# tonj sd
# kapaa us
# ushuaia ar
# yeniseysk ru
# sentyabrskiy ru
# vaini to
# puerto ayora ec
# kaitangata nz
# umzimvubu za
# puerto ayora ec
# port blair in
# upernavik gl
# tuatapere nz
# grand gaube mu
# busselton au
# butaritari ki
# arkhara ru
# hirara jp
# saskylakh ru
# rikitea pf
# fort nelson ca
# tsihombe mg
# kavaratti in
# yellowknife ca
# tautira pf
# khonuu ru
# vaini to
# monywa mm
# airai pw
# bilibino ru
# torbay ca
# souillac mu
# busselton au
# lompoc us
# havre us
# port alfred za
# muravlenko ru
# tilichiki ru
# half moon bay us
# vaini to
# kapaa us
# saint-philippe re
# mergui mm
# punta arenas cl
# cape town za
# belushya guba ru
# pacific grove us
# mount isa au
# kapaa us
# punta arenas cl
# dingle ie
# rikitea pf
# ushuaia ar
# homer us
# atuona pf
# bluff nz
# mataura pf
# mount isa au
# mezhdurechensk ru
# bandarbeyla so
# puerto ayora ec
# butaritari ki
# arraial do cabo br
# dikson ru
# vaini to
# caravelas br
# upernavik gl
# bluff nz
# bluff nz
# santa ana pe
# rikitea pf
# kodiak us
# clyde river ca
# shirvan ir
# sawtell au
# katsuura jp
# mataura pf
# punta arenas cl
# bluff nz
# pemberton ca
# tsihombe mg
# samalaeulu ws
# saint-philippe re
# ponta do sol cv
# tonantins br
# marcona pe
# morehead pg
# port alfred za
# bethel us
# vaini to
# chokurdakh ru
# codrington ag
# belushya guba ru
# dingle ie
# rikitea pf
# nagornyy ru
# rikitea pf
# ilulissat gl
# kapaa us
# punta arenas cl
# ambilobe mg
# thompson ca
# albany au
# rikitea pf
# maracacume br
# ushuaia ar
# busselton au
# punta arenas cl
# avarua ck
# jamestown sh
# killybegs ie
# saint-philippe re
# boende cd
# ushuaia ar
# yar-sale ru
# bredasdorp za
# huilong cn
# busselton au
# chuy uy
# kawalu id
# griffith au
# ushuaia ar
# nanortalik gl
# constitucion mx
# tuktoyaktuk ca
# rocha uy
# busselton au
# alofi nu
# ponta delgada pt
# sumbawa id
# katsiveli ua
# souillac mu
# okitipupa ng
# kodiak us
# tatarskaya kargala ru
# hithadhoo mv
# umzimvubu za
# lewisville us
# bredasdorp za
# georgetown sh
# kahului us
# nueva helvecia uy
# qaanaaq gl
# taolanaro mg
# rio gallegos ar
# rafai cf
# nampa us
# atuona pf
# sao joao da barra br
# atuona pf
# ushuaia ar
# punta arenas cl
# alyangula au
# hambantota lk
# amderma ru
# mar del plata ar
# illoqqortoormiut gl
# albany au
# alugan ph
# taolanaro mg
# vila velha br
# kodiak us
# busselton au
# busselton au
# pilao arcado br
# longyearbyen sj
# georgetown sh
# punta arenas cl
# doha kw
# belaya gora ru
# busselton au
# new norfolk au
# jamestown sh
# shellbrook ca
# ponta do sol cv
# cayenne gf
# dunedin nz
# saint-denis re
# lasa cn
# kavieng pg
# sola vu
# polewali id
# porbandar in
# hithadhoo mv
# tilichiki ru
# khatanga ru
# hilo us
# tuktoyaktuk ca
# punta arenas cl
# caronport ca
# ushuaia ar
# vardo no
# madimba tz
# hithadhoo mv
# taolanaro mg
# ocean city us
# jamestown sh
# kachiry kz
# castro cl
# punta arenas cl
# ust-tsilma ru
# whyalla au
# port lavaca us
# huangchuan cn
# saskylakh ru
# bengkulu id
# provideniya ru
# kapaa us
# ushuaia ar
# tynda ru
# namibe ao
# francisco sa br
# yellowknife ca
# new norfolk au
# bojnurd ir
# srednekolymsk ru
# qaanaaq gl
# illoqqortoormiut gl
# mitsamiouli km
# albany au
# belushya guba ru
# taolanaro mg
# torbay ca
# samarai pg
# cabedelo br
# georgetown sh
# new norfolk au
# saint george bm
# port alfred za
# vardo no
# sembakung id
# sinnamary gf
# vila velha br
# amuntai id
# kahului us
# punta arenas cl
# hermanus za
# hobart au
# jamestown sh
# sinnamary gf
# kamenskoye ru
# chuy uy
# pangoa pe
# plainview us
# saleaula ws
# punta arenas cl
# litovko ru
# kaiyuan cn
# new norfolk au
# carnarvon au
# san luis rio colorado mx
# atuona pf
# atuona pf
# tsihombe mg
# thompson ca
# codajas br
# necochea ar
# rikitea pf
# new norfolk au
# jamestown sh
# port alfred za
# palu id
# asosa et
# wulanhaote cn
# bambous virieux mu
# sombrerete mx
# mys shmidta ru
# kapaa us
# marcona pe
# albany au
# new norfolk au
# mataura pf
# bluff nz
# albany au
# saskatoon ca
# san patricio mx
# new norfolk au
# rikitea pf
# jamestown sh
# ushuaia ar
# havre-saint-pierre ca
# kodiak us
# jamestown sh
# ilulissat gl
# berlevag no
# castro cl
# ambovombe mg
# carnarvon au
# butaritari ki
# victoria sc
# busselton au
# vaini to
# cape town za
# diu in
# albany au
# wawa ca
# beloha mg
# jamestown sh
# albany au
# kapaa us
# xichang cn
# vaini to
# jamestown sh
# bengkulu id
# kaitangata nz
# kaeo nz
# atuona pf
# kabompo zm
# belushya guba ru
# cherskiy ru
# pevek ru
# mahebourg mu
# lagos pt
# beringovskiy ru
# vaitupu wf
# barentsburg sj
# ushuaia ar
# hilo us
# rikitea pf
# tiksi ru
# cuiluan cn
# ukiah us
# pimentel pe
# rikitea pf
# bredasdorp za
# cape town za
# nenjiang cn
# tsihombe mg
# cape town za
# nikolskoye ru
# qaanaaq gl
# rikitea pf
# nemuro jp
# hami cn
# hermanus za
# singkawang id
# puerto ayora ec
# carnarvon au
# arraial do cabo br
# thompson ca
# beloha mg
# mataura pf
# los llanos de aridane es
# tessalit ml
# manggar id
# hervey bay au
# punta arenas cl
# la rioja ar
# bende ng
# rikitea pf
# haapiti pf
# illoqqortoormiut gl
# albany au
# ponta do sol pt
# vila vu
# rikitea pf
# najran sa
# vardo no
# staunton us
# ushuaia ar
# souillac mu
# oksfjord no
# vaini to
# srednekolymsk ru
# san patricio mx
# saint george bm
# kapaa us
# east london za
# port elizabeth za
# chuy uy
# chuy uy
# hambantota lk
# mar del plata ar
# isangel vu
# hermanus za
# akdepe tm
# mar del plata ar
# puerto ayora ec
# punta arenas cl
# ayacucho pe
# atuona pf
# cape town za
# east london za
# bethel us
# rikitea pf
# khatanga ru
# cabedelo br
# kazalinsk kz
# bambous virieux mu
# sampit id
# ushuaia ar
# agadez ne
# toamasina mg
# mataura pf
# chokurdakh ru
# adrar dz
# mecca sa
# busselton au
# nome us
# foca ba
# jardim br
# chuy uy
# puerto ayora ec
# vaini to
# bluff nz
# bethel us
# lianran cn
# springbok za
# broken hill au
# carnarvon au
# port elizabeth za
# khatanga ru
# albany au
# ilulissat gl
# new norfolk au
# mar del plata ar
# hithadhoo mv
# torbay ca
# vitorino freire br
# baie-comeau ca
# barrow us
# jinxiang cn
# mecca sa
# luderitz na
# mount gambier au
# warqla dz
# clarence town bs
# cabo san lucas mx
# nizhneyansk ru
# luderitz na
# louisbourg ca
# korla cn
# busselton au
# tuatapere nz
# chapais ca
# rikitea pf
# bredasdorp za
# port alfred za
# rikitea pf
# cape town za
# bluff nz
# kapaa us
# hermanus za
# rikitea pf
# rikitea pf
# lebu cl
# nikolskoye ru
# ponta do sol cv
# mrirt ma
# saint-philippe re
# benguela ao
# qaanaaq gl
# ushuaia ar
# chickasha us
# bredasdorp za
# bowen au
# port alfred za
# korla cn
# avarua ck
# kununurra au
# cape town za
# nizhneyansk ru
# yagodnoye ru
# aklavik ca
# busselton au
# hermanus za
# fairbanks us
# punta arenas cl
# laramie us
# hambantota lk
# xining cn
# ushuaia ar
# yellowknife ca
# ribeira grande pt
# belushya guba ru
# port elizabeth za
# te anau nz
# palmer us
# ushuaia ar
# norman wells ca
# arraial do cabo br
# vaini to
# lamu ke
# saint-philippe re
# hilo us
# avarua ck
# bilma ne
# leh in
# kosonsoy uz
# porto novo cv
# dingle ie
# upernavik gl
# egvekinot ru
# vaini to
# nikolskoye ru
# butaritari ki
# nemuro jp
# thompson ca
# sola vu
# hilo us
# de-kastri ru
# caohai cn
# provideniya ru
# mys shmidta ru
# hailey us
# victoria sc
# new haven us
# port elizabeth za
# sao filipe cv
# barentsburg sj
# jiazi cn
# taolanaro mg
# pevek ru
# quatre cocos mu
# ribeira grande pt
# acapulco mx
# mataura pf
# iqaluit ca
# hailar cn
# busselton au
# zhob pk
# zarubino ru
# ponta do sol cv
# ushuaia ar
# nieuwpoort an
# cape town za
# pandhana in
# chuy uy
# jamestown sh
# rikitea pf
# hermanus za
# ostrovnoy ru
# punta arenas cl
# fortuna us
# atuona pf
# vaini to
# atuona pf
# punta arenas cl
# hithadhoo mv
# kruisfontein za
# palmas br
# east london za
# atuona pf
# rikitea pf
# butaritari ki
# mar del plata ar
# bilibino ru
# kieta pg
# saint george bm
# souillac mu
# jamestown sh
# mahebourg mu
# zamora es
# mar del plata ar
# lorengau pg
# chandur in
# mar del plata ar
# cidreira br
# tongliao cn
# mataura pf
# tarbagatay ru
# rikitea pf
# rikitea pf
# mataura pf
# jamestown sh
# korla cn
# barrow us
# nikolskoye ru
# hermanus za
# sataua ws
# punta arenas cl
# puerto ayora ec
# bluff nz
# swan hill au
# cape town za
# melfi td
# avarua ck
# langenburg ca
# puerto ayora ec
# atuona pf
# teguldet ru
# warqla dz
# geraldton au
# kodiak us
# hermanus za
# mataura pf
# abu dhabi ae
# hobart au
# ovre ardal no
# punta arenas cl
# lagunas pe
# kautokeino no
# hermanus za
# saint-augustin ca
# nanortalik gl
# port alfred za
# ribeira grande pt
# castleford gb
# sug-aksy ru
# svetlyy ru
# zhigansk ru
# east london za
# sayula mx
# chumikan ru
# vaini to
# qaanaaq gl
# mys shmidta ru
# ambanja mg
# pangnirtung ca
# bolonchen mx
# rio branco br
# lebu cl
# mataura pf
# simao cn
# mehamn no
# khatanga ru
# srednekolymsk ru
# carnarvon au
# cabedelo br
# thompson ca
# ushuaia ar
# lufilufi ws
# taolanaro mg
# hilo us
# busselton au
# rancho san diego us
# bonfim br
# mataura pf
# palimbang ph
# mataura pf
# adre td
# ostrovnoy ru
# pisco pe
# okhotsk ru
# arraial do cabo br
# sitka us
# clarksburg us
# hobart au
# chuy uy
# saint-philippe re
# pedernales do
# taolanaro mg
# tasiilaq gl
# east london za
# kostomuksha ru
# ouadda cf
# pevek ru
# provideniya ru
# bor tr
# sentyabrskiy ru
# busselton au
# santo augusto br
# jamestown sh
# acapulco mx
# belushya guba ru
# puerto ayora ec
# kapaa us
# bengkulu id
# mahebourg mu
# la asuncion ve
# pevek ru
# busselton au
# mataura pf
# punta arenas cl
# sakakah sa
# hithadhoo mv
# puerto ayora ec
# hermanus za
# christchurch nz
# albany au
# kapaa us
# kashary ru
# hermanus za
# mahebourg mu
# faya td
# pevek ru
# punta arenas cl
# cockburn town bs
# klaksvik fo
# omboue ga
# kapaa us
# puerto ayora ec
# hamilton bm
# kapaa us
# victoria sc
# bonavista ca
# gamba ga
# saskylakh ru
# rikitea pf
# illoqqortoormiut gl
# atuona pf
# ushuaia ar
# barrow us
# rambha in
# udachnyy ru
# albany au
# ahuimanu us
# thompson ca
# dikson ru
# mataura pf
# cabo san lucas mx
# puerto ayora ec
# kapaa us
# tuy hoa vn
# barrow us
# north bend us
# mar del plata ar
# havre-saint-pierre ca
# ushuaia ar
# pandan ph
# pedasi pa
# mhlume sz
# punta arenas cl
# santa fe cu
# severo-kurilsk ru
# ixtapa mx
# lincoln us
# cockburn town bs
# hermanus za
# tuktoyaktuk ca
# kapaa us
# barentsburg sj
# awbari ly
# chuy uy
# caiaponia br
# ugoofaaru mv
# souillac mu
# saqqez ir
# sitka us
# lebu cl
# tambacounda sn
# mataura pf
# flinders au
# hermanus za
# rikitea pf
# punta arenas cl
# butaritari ki
# mataura pf
# hermanus za
# hilo us
# mogadishu so
# maposeni tz
# heze cn
# pueblo nuevo mx
# yellowknife ca
# taolanaro mg
# belushya guba ru
# punta arenas cl
# ushuaia ar
# punta arenas cl
# gurgan az
# taolanaro mg
# bredasdorp za
# selkirk ca
# hobart au
# albany au
# chengde cn
# mataura pf
# berlevag no
# cape town za
# ugoofaaru mv
# albany au
# hobart au
# saint george bm
# grafton au
# rikitea pf
# arraial do cabo br
# port alfred za
# yellowknife ca
# kavieng pg
# iqaluit ca
# nome us
# ushuaia ar
# ilebo cd
# hualmay pe
# leh in
# rawannawi ki
# mariental na
# baturaja id
# rikitea pf
# taolanaro mg
# sao joao da barra br
# praya id
# bredasdorp za
# dikson ru
# rikitea pf
# busselton au
# cartagena co
# tilichiki ru
# manokwari id
# kapaa us
# karauzyak uz
# nara ml
# port elizabeth za
# nueva loja ec
# roding de
# bluff nz
# ilulissat gl
# punta arenas cl
# bahia de caraquez ec
# bilma ne
# saint-philippe re
# sola vu
# ous ru
# umm kaddadah sd
# mataura pf
# nikolskoye ru
# busselton au
# odweyne so
# souillac mu
# upernavik gl
# victor harbor au
# papara pf
# kulhudhuffushi mv
# rikitea pf
# bluff nz
# onguday ru
# clyde river ca
# jamestown sh
# mar del plata ar
# walvis bay na
# yar-sale ru
# ostrovnoy ru
# umba ru
# bethel us
# avarua ck
# kahului us
# hargeysa so
# broome au
# marawi sd
# mys shmidta ru
# mataura pf
# saleaula ws
# ushuaia ar
# nevelsk ru
# jamestown sh
# bluff nz
# zhurivka ua
# illoqqortoormiut gl
# barentsburg sj
# saryshagan kz
# duz tn
# evora pt
# tessalit ml
# florianopolis br
# turukhansk ru
# rikitea pf
# mataura pf
# katherine au
# mataura pf
# illoqqortoormiut gl
# dzhusaly kz
# christchurch nz
# kodiak us
# taolanaro mg
# emerald au
# poum nc
# ojinaga mx
# ushuaia ar
# san cristobal ec
# hobart au
# rikitea pf
# butaritari ki
# ushuaia ar
# mataura pf
# ergani tr
# janakpur np
# torbay ca
# bushehr ir
# busselton au
# saundatti yellamma in
# cape town za
# tasiilaq gl
# barrhead ca
# mweka cd
# lucapa ao
# rikitea pf
# hilo us
# soyo ao
# mataura pf
# attawapiskat ca
# plateros mx
# porto novo cv
# busselton au
# scarborough gb
# saskylakh ru
# marand ir
# nouadhibou mr
# punta arenas cl
# taolanaro mg
# albany au
# tocopilla cl
# rikitea pf
# bethel us
# punta arenas cl
# mataura pf
# salalah om
# caborca mx
# port alfred za
# hithadhoo mv
# qaanaaq gl
# constitucion cl
# pevek ru
# mataura pf
# liverpool ca
# buin pg
# codrington ag
# barrow us
# georgetown sh
# vaini to
# san ramon bo
# butaritari ki
# yellowknife ca
# alofi nu
# namibe ao
# sabha ly
# hilo us
# illoqqortoormiut gl
# bluff nz
# katsuura jp
# taolanaro mg
# severo-kurilsk ru
# mataura pf
# herat af
# vaitupu wf
# jamestown sh
# port alfred za
# avarua ck
# ushuaia ar
# arraial do cabo br
# college us
# darhan mn
# rawson ar
# buala sb
# aklavik ca
# ushuaia ar
# avarua ck
# punta arenas cl
# mayo ca
# rikitea pf
# puerto ayora ec
# nikolskoye ru
# amuntai id
# zyryanka ru
# vaini to
# yangambi cd
# ancud cl
# mataura pf
# hilo us
# hithadhoo mv
# rikitea pf
# taolanaro mg
# rikitea pf
# georgetown sh
# zhangjiakou cn
# arraial do cabo br
# mataura pf
# hermanus za
# tabou ci
# bara sd
# kavaratti in
# bodden town ky
# fortuna us
# kapaa us
# sisimiut gl
# bethel us
# mao td
# lebu cl
# namibe ao
# jalu ly
# lebu cl
# castro cl
# amderma ru
# mahdalynivka ua
# ozgon kg
# cabo san lucas mx
# cidreira br
# kapaa us
# cape town za
# yellowknife ca
# ushuaia ar
# dudinka ru
# barrow us
# kapaa us
# hokitika nz
# sentyabrskiy ru
# nushki pk
# east london za
# chokurdakh ru
# kapaa us
# pangnirtung ca
# east london za
# bluff nz
# cape town za
# narsaq gl
# turkistan kz
# yellowknife ca
# mataura pf
# nizhneyansk ru
# butterworth za
# cape town za
# arlit ne
# nizhneyansk ru
# krasnogvardeyskiy ru
# rikitea pf
# khatanga ru
# vaitupu wf
# falealupo ws
# sisak hr
# naze jp
# norman wells ca
# nome us
# waipawa nz
# ushuaia ar
# mataura pf
# ushuaia ar
# talnakh ru
# rio gallegos ar
# butaritari ki
# port alfred za
# nizhneyansk ru
# bethel us
# rikitea pf
# renqiu cn
# rikitea pf
# ningbo cn
# champerico gt
# puerto ayora ec
# taolanaro mg
# punta arenas cl
# shenjiamen cn
# ushuaia ar
# camana pe
# hobart au
# saldanha za
# devonport au
# avarua ck
# punta arenas cl
# atuona pf
# ushuaia ar
# bengkulu id
# ahipara nz
# hithadhoo mv
# sao caetano de odivelas br
# arraial do cabo br
# grand river south east mu
# port alfred za
# kapaa us
# clyde river ca
# ribeira grande pt
# puerto ayora ec
# ushuaia ar
# tuktoyaktuk ca
# dudinka ru
# barcelona ve
# qaanaaq gl
# rikitea pf
# portland au
# mar del plata ar
# vaitupu wf
# bredasdorp za
# belyy yar ru
# zaozerne ua
# padang id
# codrington ag
# khatanga ru
# mataura pf
# port macquarie au
# grand river south east mu
# dzhusaly kz
# rikitea pf
# yumen cn
# havelock us
# caravelas br
# yulara au
# barrow us
# ipil ph
# illoqqortoormiut gl
# ulaangom mn
# gornozavodsk ru
# mataura pf
# ushuaia ar
# sao joao da barra br
# hermanus za
# aracaju br
# saldanha za
# buala sb
# salalah om
# buala sb
# hudson bay ca
# tasiilaq gl
# warrnambool au
# sorland no
# camalu mx
# atuona pf
# mys shmidta ru
# luderitz na
# altamont us
# busselton au
# kitimat ca
# castro cl
# khatanga ru
# panzhihua cn
# busselton au
# albany au
# krasnoselkup ru
# east london za
# yar-sale ru
# yellowknife ca
# barrow us
# upernavik gl
# atambua id
# jamestown sh
# rikitea pf
# quballat tn
# panjab af
# nizhneyansk ru
# kahului us
# tiksi ru
# chimore bo
# mataura pf
# mabaruma gy
# saint-philippe re
# upernavik gl
# cabo san lucas mx
# rikitea pf
# mitsamiouli km
# merrill us
# tuktoyaktuk ca
# fortuna us
# kodiak us
# torbay ca
# rikitea pf
# port alfred za
# faanui pf
# rikitea pf
# ushuaia ar
# castro cl
# hobart au
# noumea nc
# qaanaaq gl
# saint-augustin ca
# jamestown sh
# petatlan mx
# barrow us
# rikitea pf
# tuktoyaktuk ca
# provideniya ru
# emerald au
# punta arenas cl
# chopda in
# khatanga ru
# khatanga ru
# tuktoyaktuk ca
# ushuaia ar
# ixtapa mx
# warqla dz
# hobart au
# albany au
# busselton au
# hithadhoo mv
# vaini to
# monaco-ville mc
# yar-sale ru
# ushuaia ar
# novoagansk ru
# mar del plata ar
# ancud cl
# atuona pf
# wattegama lk
# betlitsa ru
# cayenne gf
# karambakkudi in
# qaanaaq gl
# atuona pf
# butaritari ki
# vaini to
# dikson ru
# turukhansk ru

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
city = cities
len(city)
# Out:
# 597

# %%
print("Beginning Data Retrieval     ")
print("-----------------------------")

#loop through cities list
for cities in range(len(cities)): #how do I make this work for 500+ cities????
    
    #Group cities in sets of 50
    if i % 50 == 0 and i >=50:
    #    ^ means remainder of i/50     
    #two different counters will be needed for this step
        
        #1 one to log city count (1 to 50)
        set_count +=1
        #2 another for sets
        record_count = 1
        #can only call data once every minute
        time.sleep(60)
        
    #build city_url for each city
    city_url = url + "&q=" + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {cities}")
    # Add 1 to the record count.
    record_count += 1
    
    #Make API request for each city
    try:
        city_weather = requests.get(city_url).json()
        #Parse JSON weather for:
        #latitude and longitude
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        #max temp
        city_max_temp = city_weather["main"]["temp_max"]
        #humidity
        city_humidity = city_weather["main"]["humidity"]
        #Cloudiness
        city_clouds = city_weather["clouds"]["all"]
        #wind speed
        city_wind = city_weather["wind"]["speed"]
        #City, country, and date
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": cities[i],
                          "Lat": city_lat,
                          "Lng": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         })
    except:
        print(f"City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | broken hill
# Processing Record 27 of Set 1 | udimskiy
# Processing Record 28 of Set 1 | kruisfontein
# Processing Record 29 of Set 1 | tecoanapa
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | victoria
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | oyama
# Processing Record 45 of Set 1 | svetlaya
# Processing Record 46 of Set 1 | sungaipenuh
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | vilyuysk
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 51 of Set 1 | zelenoborskiy
# Processing Record 52 of Set 1 | tuktoyaktuk
# Processing Record 53 of Set 1 | punta arenas
# Processing Record 54 of Set 1 | cherskiy
# Processing Record 55 of Set 1 | kedrovyy
# Processing Record 56 of Set 1 | hobart
# Processing Record 57 of Set 1 | izhmorskiy
# Processing Record 58 of Set 1 | kovur
# Processing Record 59 of Set 1 | vaini
# Processing Record 60 of Set 1 | chokurdakh
# Processing Record 61 of Set 1 | fort nelson
# Processing Record 62 of Set 1 | rapar
# Processing Record 63 of Set 1 | alofi
# Processing Record 64 of Set 1 | gizo
# Processing Record 65 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 66 of Set 1 | champerico
# Processing Record 67 of Set 1 | kutum
# Processing Record 68 of Set 1 | sao filipe
# Processing Record 69 of Set 1 | barrow
# Processing Record 70 of Set 1 | airai
# Processing Record 71 of Set 1 | saint-philippe
# Processing Record 72 of Set 1 | naze
# Processing Record 73 of Set 1 | los llanos de aridane
# Processing Record 74 of Set 1 | aras
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | taoudenni
# Processing Record 4 of Set 2 | lagoa
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | portland
# Processing Record 8 of Set 2 | asau
# Processing Record 9 of Set 2 | sorong
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | bandarbeyla
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | oudtshoorn
# Processing Record 16 of Set 2 | ucluelet
# Processing Record 17 of Set 2 | waipawa
# Processing Record 18 of Set 2 | pak phanang
# Processing Record 19 of Set 2 | saint-pierre
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | salekhard
# Processing Record 23 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | kenora
# Processing Record 27 of Set 2 | verkhnyaya inta
# Processing Record 28 of Set 2 | charters towers
# Processing Record 29 of Set 2 | vila franca do campo
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | westport
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | lethem
# Processing Record 34 of Set 2 | egvekinot
# Processing Record 35 of Set 2 | pisco
# Processing Record 36 of Set 2 | linxia
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | parelhas
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | bellefontaine
# Processing Record 44 of Set 2 | ambulu
# Processing Record 45 of Set 2 | ust-kuyga
# Processing Record 46 of Set 2 | taltal
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | samsun
# Processing Record 49 of Set 2 | cayenne
# Processing Record 50 of Set 2 | muriti
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | yushan
# Processing Record 4 of Set 3 | pangkalanbuun
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | yongchang
# Processing Record 9 of Set 3 | hastings
# Processing Record 10 of Set 3 | talaya
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | rocha
# Processing Record 14 of Set 3 | seddon
# Processing Record 15 of Set 3 | amahai
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | canitas
# City not found. Skipping...
# Processing Record 18 of Set 3 | leningradskiy
# Processing Record 19 of Set 3 | jiayuguan
# Processing Record 20 of Set 3 | montepuez
# Processing Record 21 of Set 3 | kavaratti
# Processing Record 22 of Set 3 | saint anthony
# Processing Record 23 of Set 3 | belmonte
# Processing Record 24 of Set 3 | harrisburg
# Processing Record 25 of Set 3 | ketchikan
# Processing Record 26 of Set 3 | iztapa
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | agustin codazzi
# Processing Record 29 of Set 3 | arman
# Processing Record 30 of Set 3 | provideniya
# Processing Record 31 of Set 3 | sibolga
# Processing Record 32 of Set 3 | port elizabeth
# Processing Record 33 of Set 3 | segezha
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | libertador general san martin
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | raudeberg
# Processing Record 38 of Set 3 | fort-shevchenko
# Processing Record 39 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | grand gaube
# Processing Record 42 of Set 3 | victoria point
# Processing Record 43 of Set 3 | kushima
# Processing Record 44 of Set 3 | marang
# Processing Record 45 of Set 3 | gaogou
# Processing Record 46 of Set 3 | zaykovo
# Processing Record 47 of Set 3 | srednekolymsk
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 3 | codrington
# Processing Record 1 of Set 4 | la ligua
# Processing Record 2 of Set 4 | rio casca
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 4 | abu dhabi
# Processing Record 6 of Set 4 | east london
# Processing Record 7 of Set 4 | mormugao
# Processing Record 8 of Set 4 | seoul
# Processing Record 9 of Set 4 | sakakah
# Processing Record 10 of Set 4 | yumen
# Processing Record 11 of Set 4 | ceres
# Processing Record 12 of Set 4 | shiraz
# Processing Record 13 of Set 4 | chalette-sur-loing
# Processing Record 14 of Set 4 | puerto escondido
# Processing Record 15 of Set 4 | hasaki
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | northam
# Processing Record 18 of Set 4 | iracoubo
# Processing Record 19 of Set 4 | harlow
# Processing Record 20 of Set 4 | saint-francois
# Processing Record 21 of Set 4 | mandalgovi
# Processing Record 22 of Set 4 | shakawe
# Processing Record 23 of Set 4 | mogadishu
# Processing Record 24 of Set 4 | nueva loja
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | pestravka
# Processing Record 27 of Set 4 | svirstroy
# Processing Record 28 of Set 4 | okhotsk
# Processing Record 29 of Set 4 | zlatoustovsk
# City not found. Skipping...
# Processing Record 30 of Set 4 | jiazi
# Processing Record 31 of Set 4 | chimoio

# %%
#Add data to list in a dictionary format and convert list to data frame
import pandas as pd
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tuktoyaktuk  69.4541 -133.0374    -19.59        98          43
# 1           Hermanus -34.4187   19.2345     73.80        51          86
# 2              Bluff -46.6000  168.3333     58.91        83         100
# 3        Port Alfred -33.5906   26.8910     91.71        40          89
# 4              Outjo -20.1167   16.1500     88.11        21          19
# 5             Agadez  19.7500   10.2500     89.17         3           3
# 6  Paso De Los Toros -32.8167  -56.5167     70.70        64           0
# 7             Avarua -21.2078 -159.7750     71.65       100          91
# 8             Taltal -25.4000  -70.4833     65.73        75          30
# 9              Airai  -8.9266  125.4092     61.03        95          99
#
#    Wind Speed Country                 Date
# 0        7.18      CA  2022-03-28 13:05:45
# 1       22.66      ZA  2022-03-28 13:05:45
# 2        6.06      NZ  2022-03-28 13:05:46
# 3        8.55      ZA  2022-03-28 13:03:12
# 4       12.71      NA  2022-03-28 13:05:47
# 5       14.00      NE  2022-03-28 13:04:42
# 6        7.87      UY  2022-03-28 13:05:48
# 7        3.44      CK  2022-03-28 13:01:34
# 8        2.10      CL  2022-03-28 13:05:49
# 9        1.45      TL  2022-03-28 13:05:49

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
import time
# %matplotlib inline
import matplotlib.pyplot as plt

today = time.strftime("%x")

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

#Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature " + today)
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#save figure
plt.savefig("weather_data/Fig1.png")

plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

#git add / commit / push once I get it working for 500+ cities
