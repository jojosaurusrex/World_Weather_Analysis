# %%
# Import the random module.
import random

# Import the NumPy module.
import numpy as np

random.random()
# Out:
# 0.7894649965954906

# %%
random.randint(-100,100)
# Out:
# -32

# %%
random.randrange(-47,47,1)
# Out:
# 45

# %%
random.randrange(-90, 90, step=3)
# Out:
# -24

# %%
random.uniform(-4,4)
# Out:
# -3.336750566697182

# %%
randomNum = random.randint(-90,89) + random.random()
randomNum
# Out:
# -10.913651631221489

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
    
latitudes
# Out:
# [-52.935212387798344,
#  66.26618555616969,
#  -40.902425619211996,
#  58.70605377913146,
#  12.65288161779422,
#  -29.56041561555144,
#  59.80763926322661,
#  1.252225861470719,
#  45.95383683126695,
#  64.39833884846006]

# %%
random.uniform(-90,90)
# Out:
# -31.859962617463545

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -65.74565912538007

# %%
np.random.uniform(low=-90, high=90)
# Out:
# 60.531099561373736

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 53.7222408 , -22.05306447, -65.71100085, -14.59310996,
#         30.82934913,  -0.97539024,  52.8794733 , -48.4093444 ,
#        -82.60170232,  58.76163568,  -6.15021401, -49.6760065 ,
#         53.96918693, -21.05339918,  69.97091438,  64.42130947,
#        -36.77571735,  37.01949422,  33.55982328,  80.63453367,
#        -65.06622357, -64.91166244,  22.32707486,  15.65386602,
#        -17.46326954,   7.26377114,  75.15674713, -21.13137346,
#        -11.41310509,  31.8151615 , -28.77693191, -26.42351562,
#         66.30330026,  43.89883392, -60.40260586,   2.13266886,
#         33.14997189, -57.54634121,  82.17522494, -76.87107428,
#        -81.38001052,  24.69747561, -43.97993527, -32.53629862,
#        -17.6726716 ,   1.25494254,  -2.40798224,  67.63663552,
#         84.62411113, -31.38545042])

# %%
# Import timeit.
import timeit

#output is time it took to run code 7 times and 100000 loops per run
# this is ~120x faster than the method below
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 9.43 µs ± 32.1 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes

# Call the function with 1500.
#output is time it took to run code 7 times and 1000 loops per run

# %timeit latitudes(1500)
# Out:
# 1.11 ms ± 4.35 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# not sure how to do this. HELP???

#Refactor the code for the while loop with the %timeit magic command & 
#Write a for loop that will generate the 1,500 latitudes.


def latitudes(size):
    latitudes = []
    x = 0
    for x in range(size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes

# Call the function with 1500.
#output is time it took to run code 7 times and 1000 loops per run

# %timeit latitudes(1500)
# Out:
# 1.13 ms ± 4.74 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
#is this how you unzip?
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# carnarvon au
# east london za
# butaritari ki
# pala td
# kapaa us
# tuktoyaktuk ca
# bluff nz
# busselton au
# barentsburg sj
# uyemskiy ru
# rikitea pf
# gedo et
# pobe bj
# atuona pf
# cape town za
# butaritari ki
# bethel us
# merauke id
# grand river south east mu
# nouadhibou mr
# sokoni tz
# tuktoyaktuk ca
# mataura pf
# bathsheba bb
# kapaa us
# vostok ru
# bluff nz
# gurgan az
# vila velha br
# qaanaaq gl
# rikitea pf
# ribeira grande pt
# kavieng pg
# domoni km
# sao paulo de olivenca br
# dikson ru
# ambon id
# busselton au
# asau tv
# rikitea pf
# olenino ru
# albany au
# dingle ie
# carnarvon au
# ayan ru
# norman wells ca
# thompson ca
# lompoc us
# attawapiskat ca
# saint-philippe re
# kavaratti in
# hatton lk
# saskylakh ru
# avarua ck
# torbay ca
# new norfolk au
# ponta delgada pt
# strelka ru
# birobidzhan ru
# albany au
# piranshahr ir
# praia da vitoria pt
# kruisfontein za
# busselton au
# ostrovnoy ru
# pravia es
# cidreira br
# atuona pf
# vaini to
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 614
